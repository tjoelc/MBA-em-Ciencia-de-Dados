# %% [markdown]
# ### Exercicios com Pandas

# %% [markdown]
#  aluno : joel campos teixeira

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Criação de Series e DataFrames
#
# Crie uma Series chamada s com os valores [10, 20, 30, 40, 50].

# %%
s = pd.Series([10,20,30,40,50])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# Crie uma Series com os valores [1.5, 2.5, 3.5, 4.5] e com índices personalizados como 'a', 'b', 'c', 'd'.

# %%
s2 = pd.Series(data=[1.5, 2.5, 3.5, 4.5],index=['a', 'b', 'c', 'd'])
s2
# Out:
# a    1.5
# b    2.5
# c    3.5
# d    4.5
# dtype: float64

# %% [markdown]
# Crie um DataFrame chamado df com os dados abaixo:
#
# Nome   Idade
# Ana    25
# Bruno  30
# Carla  27

# %%
df= pd.DataFrame({'Nome': ['Ana','Bruno','Carla'],
                   'Idade': [25, 30, 27]})
df
# Out:
#     Nome  Idade
# 0    Ana     25
# 1  Bruno     30
# 2  Carla     27

# %% [markdown]
# Crie um DataFrame com 3 colunas (Produto, Preço, Quantidade) e pelo menos 5 linhas de dados.

# %%
df2= pd.DataFrame({'Produto':['p1','p2','p3','p4','p5'],
                    'Preço':[40.00,60.00,30.00,88.00,50.00],
                    'Quantidade':[5,15,7,12,8]})
df2
# Out:
#   Produto  Preço  Quantidade
# 0      p1   40.0           5
# 1      p2   60.0          15
# 2      p3   30.0           7
# 3      p4   88.0          12
# 4      p5   50.0           8

# %% [markdown]
# Crie um DataFrame de uma matriz 3x3 preenchida com números aleatórios entre 0 e 100.

# %%
df=pd.DataFrame(np.random.randint(0,100,size=(3,3)),columns=['A','B','C'])
df
# Out:
#     A   B   C
# 0  43  67  49
# 1  11  87  82
# 2  46   8  67

# %% [markdown]
# Consulta de Dados
# Exiba os primeiros 3 elementos da Series s.

# %%
s.head(3)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
# Exiba a primeira linha do DataFrame df.
# Selecione apenas a coluna Nome do DataFrame df.

# %%
df.head(1)
# Out:
#     A   B   C
# 0  43  67  49

# %% [markdown]
# Exiba as últimas duas linhas do DataFrame criado na questão 4.

# %%
df.tail(2)
# Out:
#     Nome  Idade
# 1  Bruno     30
# 2  Carla     27

# %% [markdown]
# Consulte as linhas onde o Preço é maior que 50 no DataFrame criado na questão 4.

# %%
df2[df2['Preço'] > 50]
# Out:
#   Produto  Preço  Quantidade
# 1      p2   60.0          15
# 3      p4   88.0          12

# %% [markdown]
# Manipulação de Series e DataFrames
# Adicione uma nova coluna Desconto ao DataFrame df com o valor 5% para todos os produtos.

# %%
df2['Desconto'] =0.05
df2

Atualize o valor de Quantidade para 0 no produto da primeira linha do DataFrame criado na questão 4.

# %%
df.loc[0,'Quantidade'] = 0
df
# Out:
#     Nome  Idade  Quantidade
# 0    Ana     25         0.0
# 1  Bruno     30         NaN
# 2  Carla     27         NaN

# %% [markdown]
# Renomeie a coluna Idade do DataFrame df para Anos.

# %%
df2.rename(columns={'Desconto': 'Desc'},inplace= True)
df2
# Out:
#   Produto  Preço  Quantidade  Desc
# 0      p1   40.0           5  0.05
# 1      p2   60.0          15  0.05
# 2      p3   30.0           7  0.05
# 3      p4   88.0          12  0.05
# 4      p5   50.0           8  0.05

# %% [markdown]
# Ordene o DataFrame df por Preço em ordem decrescente.

# %%
df2.sort_values(by='Preço',ascending=False, inplace= True)
df2
# Out:
#   Produto  Preço  Quantidade  Desc
# 3      p4   88.0          12  0.05
# 1      p2   60.0          15  0.05
# 4      p5   50.0           8  0.05
# 0      p1   40.0           5  0.05
# 2      p3   30.0           7  0.05

# %%
df.sort_values(by='Idade' ,ascending =False)
# Out:
#     Nome  Idade  Quantidade
# 1  Bruno     30         NaN
# 2  Carla     27         NaN
# 0    Ana     25         0.0

# %% [markdown]
# Filtre e exiba apenas as linhas do DataFrame onde Quantidade é maior que 10.

# %%
df2[df2['Quantidade']>10]
# Out:
#   Produto  Preço  Quantidade  Desc
# 3      p4   88.0          12  0.05
# 1      p2   60.0          15  0.05

# %% [markdown]
# Operações de Estatística e Agregação
# Calcule a média da Series s.

# %%
s.mean()
# Out:
# np.float64(30.0)

# %% [markdown]
# Encontre o valor máximo da coluna Quantidade no DataFrame criado na questão 4.

# %%
max(df2['Quantidade'])
# Out:
# 15

# %% [markdown]
# Calcule a soma da coluna Preço no DataFrame criado na questão 4.

# %%
sum(df2['Preço'])
# Out:
# 268.0

# %% [markdown]
# Encontre o produto com a maior quantidade no DataFrame da questão 4.
# Exiba as estatísticas descritivas (describe) do DataFrame df.

# %%
df2.loc[df2['Quantidade'].idxmax()]
# Out:
# Produto         p2
# Preço         60.0
# Quantidade      15
# Desc          0.05
# Name: 1, dtype: object

# %%
df.describe()
# Out:
#            Idade  Quantidade
# count   3.000000         1.0
# mean   27.333333         0.0
# std     2.516611         NaN
# min    25.000000         0.0
# 25%    26.000000         0.0
# 50%    27.000000         0.0
# 75%    28.500000         0.0
# max    30.000000         0.0

# %% [markdown]
# Operações de Exclusão e Reindexação
# Exclua a primeira linha do DataFrame df.
# Exclua a coluna Desconto do DataFrame df.

# %%
df
# Out:
#     Nome  Idade  Quantidade
# 0    Ana     25         0.0
# 1  Bruno     30         NaN
# 2  Carla     27         NaN

# %%
df.drop(index=0, inplace= True)
df
# Out:
#     Nome  Idade  Quantidade
# 1  Bruno     30         NaN
# 2  Carla     27         NaN

# %%
df2.drop(columns=['Desc'],inplace = True)
df2
# Out:
#   Produto  Preço  Quantidade
# 3      p4   88.0          12
# 1      p2   60.0          15
# 4      p5   50.0           8
# 0      p1   40.0           5
# 2      p3   30.0           7

# %% [markdown]
# Resete o índice do DataFrame df sem manter o índice antigo.
# Reordene o índice da Series s para [4, 3, 2, 1, 0].

# %%
df.reset_index(drop= True,inplace=True)
df
# Out:
#     Nome  Idade  Quantidade
# 0  Bruno     30         NaN
# 1  Carla     27         NaN

# %% [markdown]
# Remova as linhas com valores nulos no DataFrame da questão 4 (adicione nulos antes, se necessário).

# %%
df
# Out:
#     Nome  Idade  Quantidade
# 0  Bruno     30         NaN
# 1  Carla     27         NaN

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Nome, Idade, Quantidade]
# Index: []

# %%
df['Nome']='Joel'

# %%
df
# Out:
#    Nome  Idade  Quantidade
# 0  Joel     30         NaN
# 1  Joel     27         NaN

# %% [markdown]
# Operações de Fusão e Junção
# Crie outro DataFrame chamado df_novo com uma coluna Nome e Cidade e faça uma junção com o DataFrame df usando Nome como chave.

# %%
dfn={'Nome':['Hosss','Gulbert'],
     'Cidade':['Maranha','Paulina']}
dfn
# Out:
# {'Nome': ['Hosss', 'Gulbert'], 'Cidade': ['Maranha', 'Paulina']}

# %%
dfn

dfn.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[117], line 3
#       1 dfn
# ----> 3 dfn.head()
#
# AttributeError: 'dict' object has no attribute 'head'

# %% [markdown]
# Junte duas Series, s1 e s2, com os valores [1, 2, 3] e [4, 5, 6], respectivamente.

# %%
s1= pd.Series(range(1,10,2))
s1
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %%
s_comb=pd.concat([s1,s2]).reset_index(drop=True)
s_comb
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# 5    1
# 6    4
# 7    7
# dtype: int64

# %% [markdown]
# Realize uma junção do DataFrame criado na questão 4 com ele mesmo usando a coluna Produto como chave.

# %%
# Out:
#    Nome  Idade  Quantidade
# 0  Joel     30         NaN
# 1  Joel     27         NaN

# %% [markdown]
# Adicione uma nova coluna ao DataFrame da questão 4 que seja o dobro do valor de Quantidade.

# %%
df2 =pd.DataFrame({
    'Nome': ['Ana', 'Bruno', 'Carla'],
    'Cidade': ['São Paulo', 'Rio de Janeiro', 'Curitiba']
})
df2
# Out:
#     Nome          Cidade
# 0    Ana       São Paulo
# 1  Bruno  Rio de Janeiro
# 2  Carla        Curitiba

# %%
df2['Idade']=[17,25,35]
df2['Idade x 2']=df2['Idade'] * 2
df2
# Out:
#     Nome          Cidade  Idade  Idade x 2
# 0    Ana       São Paulo     17         34
# 1  Bruno  Rio de Janeiro     25         50
# 2  Carla        Curitiba     35         70

# %% [markdown]
# Combine os valores de duas Series, s1 e s2, em uma nova Series sem duplicados.

# %%
tb= pd.DataFrame(np.random.randn(30,6))
tb
# Out:
#            0         1         2         3         4         5
# 0  -0.306742 -1.138526 -0.434559 -0.669912  0.295974 -0.281566
# 1   0.617344  1.327834 -0.543828 -0.814900 -0.135990  0.572402
# 2  -0.412878 -0.778992  0.058423 -1.473210  1.215427  0.432737
# 3   0.397298 -0.608018 -0.353333  0.376144 -0.515229  0.875705
# 4  -0.331104 -0.331299 -0.649619  0.759553  0.446995 -0.435313
# 5   0.191173 -0.156234 -1.583686  0.264142 -0.217845 -0.490237
# 6  -0.102533 -1.568986  0.238181 -1.386059  0.796430 -0.533745
# 7  -0.380359 -1.218736 -0.051199  1.691041 -1.462355 -1.626871
# 8   0.223180  2.323555  2.008956  0.936684 -1.040449  0.435391
# 9  -1.771120 -0.051263 -1.500375  0.682167  0.213444  1.343765
# 10  1.395654 -0.267290  0.229483  0.211915 -0.147696  0.741381
# 11  1.066107  0.599189  0.783471 -0.321524 -1.058440 -0.324473
# 12  0.680352 -0.732237 -0.151210 -0.291171 -0.696079  0.907823
# 13  0.344298  1.960448 -0.029890 -0.023697  0.756062  0.452151
# ...

# %%
for num in tb:
    tb[num-1]=num
tb
# Out:
#      0   1   2   3   4         5  -1
# 0    1   2   3   4   5 -0.281566   0
# 1    1   2   3   4   5  0.572402   0
# 2    1   2   3   4   5  0.432737   0
# 3    1   2   3   4   5  0.875705   0
# 4    1   2   3   4   5 -0.435313   0
# 5    1   2   3   4   5 -0.490237   0
# 6    1   2   3   4   5 -0.533745   0
# 7    1   2   3   4   5 -1.626871   0
# 8    1   2   3   4   5  0.435391   0
# 9    1   2   3   4   5  1.343765   0
# 10   1   2   3   4   5  0.741381   0
# 11   1   2   3   4   5 -0.324473   0
# 12   1   2   3   4   5  0.907823   0
# 13   1   2   3   4   5  0.452151   0
# 14   1   2   3   4   5  1.658380   0
# 15   1   2   3   4   5 -0.383669   0
# 16   1   2   3   4   5  0.757208   0
# 17   1   2   3   4   5 -0.175260   0
# 18   1   2   3   4   5  0.970336   0
# 19   1   2   3   4   5  0.260958   0
# 20   1   2   3   4   5  0.327252   0
# 21   1   2   3   4   5 -0.290176   0
# 22   1   2   3   4   5 -0.657645   0
# 23   1   2   3   4   5 -0.060540   0
# ...

# %%
tb.rename(columns={0:'col1', 1:'col2', 2:'col3',3:'col4',4:'col5'},inplace= True)
tb
# Out:
#      col1  col2  col3  col4  col5  -1
# L1      1     2     3     4     5   0
# L2      1     2     3     4     5   0
# L3      1     2     3     4     5   0
# L4      1     2     3     4     5   0
# L5      1     2     3     4     5   0
# L6      1     2     3     4     5   0
# L7      1     2     3     4     5   0
# L8      1     2     3     4     5   0
# L9      1     2     3     4     5   0
# L10     1     2     3     4     5   0
# 10      1     2     3     4     5   0
# 11      1     2     3     4     5   0
# 12      1     2     3     4     5   0
# 13      1     2     3     4     5   0
# 14      1     2     3     4     5   0
# 15      1     2     3     4     5   0
# 16      1     2     3     4     5   0
# 17      1     2     3     4     5   0
# 18      1     2     3     4     5   0
# 19      1     2     3     4     5   0
# 20      1     2     3     4     5   0
# 21      1     2     3     4     5   0
# 22      1     2     3     4     5   0
# 23      1     2     3     4     5   0
# ...

# %%
tb.rename(index={0:'L1', 1:'L2', 2:'L3', 3:'L4', 4:'L5', 5:'L6', 6:'L7', 7:'L8', 8:'L9', 9:'L10'},inplace=True)
tb
# Out:
#      col1  col2  col3  col4  col5  -1
# L1      1     2     3     4     5   0
# L2      1     2     3     4     5   0
# L3      1     2     3     4     5   0
# L4      1     2     3     4     5   0
# L5      1     2     3     4     5   0
# L6      1     2     3     4     5   0
# L7      1     2     3     4     5   0
# L8      1     2     3     4     5   0
# L9      1     2     3     4     5   0
# L10     1     2     3     4     5   0
# 10      1     2     3     4     5   0
# 11      1     2     3     4     5   0
# 12      1     2     3     4     5   0
# 13      1     2     3     4     5   0
# 14      1     2     3     4     5   0
# 15      1     2     3     4     5   0
# 16      1     2     3     4     5   0
# 17      1     2     3     4     5   0
# 18      1     2     3     4     5   0
# 19      1     2     3     4     5   0
# 20      1     2     3     4     5   0
# 21      1     2     3     4     5   0
# 22      1     2     3     4     5   0
# 23      1     2     3     4     5   0
# ...

# %%
tb
# Out:
#      col1  col2  col3  col4  col5  -1
# L1      1     2     3     4     5   0
# L2      1     2     3     4     5   0
# L3      1     2     3     4     5   0
# L4      1     2     3     4     5   0
# L5      1     2     3     4     5   0
# L6      1     2     3     4     5   0
# L7      1     2     3     4     5   0
# L8      1     2     3     4     5   0
# L9      1     2     3     4     5   0
# L10     1     2     3     4     5   0
# 10      1     2     3     4     5   0
# 11      1     2     3     4     5   0
# 12      1     2     3     4     5   0
# 13      1     2     3     4     5   0
# 14      1     2     3     4     5   0
# 15      1     2     3     4     5   0
# 16      1     2     3     4     5   0
# 17      1     2     3     4     5   0
# 18      1     2     3     4     5   0
# 19      1     2     3     4     5   0
# 20      1     2     3     4     5   0
# 21      1     2     3     4     5   0
# 22      1     2     3     4     5   0
# 23      1     2     3     4     5   0
# ...

# %%
tb.col5
# Out:
# L1     5
# L2     5
# L3     5
# L4     5
# L5     5
# L6     5
# L7     5
# L8     5
# L9     5
# L10    5
# 10     5
# 11     5
# 12     5
# 13     5
# 14     5
# 15     5
# 16     5
# 17     5
# 18     5
# 19     5
# 20     5
# 21     5
# 22     5
# 23     5
# 24     5
# 25     5
# 26     5
# 27     5
# 28     5
# 29     5
# Name: col5, dtype: int64

# %%
l= tb.columns.tolist()
l
# Out:
# ['col1', 'col2', 'col3', 'col4', 'col5', -1]

# %%
a= tb.columns.values
a
# Out:
# array(['col1', 'col2', 'col3', 'col4', 'col5', -1], dtype=object)

# %%
tb.rename(columns={'col1':'idade','col2':'sexo','col3':'cartão'},inplace= True)
tb
# Out:
#      idade  sexo  cartão  col4  col5  -1
# L1       1     2       3     4     5   0
# L2       1     2       3     4     5   0
# L3       1     2       3     4     5   0
# L4       1     2       3     4     5   0
# L5       1     2       3     4     5   0
# L6       1     2       3     4     5   0
# L7       1     2       3     4     5   0
# L8       1     2       3     4     5   0
# L9       1     2       3     4     5   0
# L10      1     2       3     4     5   0
# 10       1     2       3     4     5   0
# 11       1     2       3     4     5   0
# 12       1     2       3     4     5   0
# 13       1     2       3     4     5   0
# 14       1     2       3     4     5   0
# 15       1     2       3     4     5   0
# 16       1     2       3     4     5   0
# 17       1     2       3     4     5   0
# 18       1     2       3     4     5   0
# 19       1     2       3     4     5   0
# 20       1     2       3     4     5   0
# 21       1     2       3     4     5   0
# ...

# %%
s= tb['sexo']
s
# Out:
# L1     2
# L2     2
# L3     2
# L4     2
# L5     2
# L6     2
# L7     2
# L8     2
# L9     2
# L10    2
# 10     2
# 11     2
# 12     2
# 13     2
# 14     2
# 15     2
# 16     2
# 17     2
# 18     2
# 19     2
# 20     2
# 21     2
# 22     2
# 23     2
# 24     2
# 25     2
# 26     2
# 27     2
# 28     2
# 29     2
# Name: sexo, dtype: int64

# %%
tb.head()
# Out:
#     idade  sexo  cartão  col4  col5  -1
# L1      1     2       3     4     5   0
# L2      1     2       3     4     5   0
# L3      1     2       3     4     5   0
# L4      1     2       3     4     5   0
# L5      1     2       3     4     5   0

# %%
tb.tail(3)
# Out:
#     idade  sexo  cartão  col4  col5  -1
# 27      1     2       3     4     5   0
# 28      1     2       3     4     5   0
# 29      1     2       3     4     5   0

# %%
s = tb.sexo
s
# Out:
# L1     2
# L2     2
# L3     2
# L4     2
# L5     2
# L6     2
# L7     2
# L8     2
# L9     2
# L10    2
# 10     2
# 11     2
# 12     2
# 13     2
# 14     2
# 15     2
# 16     2
# 17     2
# 18     2
# 19     2
# 20     2
# 21     2
# 22     2
# 23     2
# 24     2
# 25     2
# 26     2
# 27     2
# 28     2
# 29     2
# Name: sexo, dtype: int64

# %%
tb.sexo= (tb.idade/tb.cartão)*2/3
tb
# Out:
#      idade      sexo  cartão  col4  col5  -1
# L1       1  0.222222       3     4     5   0
# L2       1  0.222222       3     4     5   0
# L3       1  0.222222       3     4     5   0
# L4       1  0.222222       3     4     5   0
# L5       1  0.222222       3     4     5   0
# L6       1  0.222222       3     4     5   0
# L7       1  0.222222       3     4     5   0
# L8       1  0.222222       3     4     5   0
# L9       1  0.222222       3     4     5   0
# L10      1  0.222222       3     4     5   0
# 10       1  0.222222       3     4     5   0
# 11       1  0.222222       3     4     5   0
# 12       1  0.222222       3     4     5   0
# 13       1  0.222222       3     4     5   0
# 14       1  0.222222       3     4     5   0
# 15       1  0.222222       3     4     5   0
# 16       1  0.222222       3     4     5   0
# 17       1  0.222222       3     4     5   0
# 18       1  0.222222       3     4     5   0
# 19       1  0.222222       3     4     5   0
# ...

# %%
tb['new col']= (tb.idade/tb.cartão)*2/3
tb
# Out:
#      idade      sexo  cartão  col4  col5  -1   new col
# L1       1  0.222222       3     4     5   0  0.222222
# L2       1  0.222222       3     4     5   0  0.222222
# L3       1  0.222222       3     4     5   0  0.222222
# L4       1  0.222222       3     4     5   0  0.222222
# L5       1  0.222222       3     4     5   0  0.222222
# L6       1  0.222222       3     4     5   0  0.222222
# L7       1  0.222222       3     4     5   0  0.222222
# L8       1  0.222222       3     4     5   0  0.222222
# L9       1  0.222222       3     4     5   0  0.222222
# L10      1  0.222222       3     4     5   0  0.222222
# 10       1  0.222222       3     4     5   0  0.222222
# 11       1  0.222222       3     4     5   0  0.222222
# 12       1  0.222222       3     4     5   0  0.222222
# 13       1  0.222222       3     4     5   0  0.222222
# 14       1  0.222222       3     4     5   0  0.222222
# 15       1  0.222222       3     4     5   0  0.222222
# ...

# %%
tb.drop(columns='new col',inplace=True)
tb
# Out:
#      idade      sexo  cartão  col4  col5  -1
# L1       1  0.222222       3     4     5   0
# L2       1  0.222222       3     4     5   0
# L3       1  0.222222       3     4     5   0
# L4       1  0.222222       3     4     5   0
# L5       1  0.222222       3     4     5   0
# L6       1  0.222222       3     4     5   0
# L7       1  0.222222       3     4     5   0
# L8       1  0.222222       3     4     5   0
# L9       1  0.222222       3     4     5   0
# L10      1  0.222222       3     4     5   0
# 10       1  0.222222       3     4     5   0
# 11       1  0.222222       3     4     5   0
# 12       1  0.222222       3     4     5   0
# 13       1  0.222222       3     4     5   0
# 14       1  0.222222       3     4     5   0
# 15       1  0.222222       3     4     5   0
# 16       1  0.222222       3     4     5   0
# 17       1  0.222222       3     4     5   0
# 18       1  0.222222       3     4     5   0
# 19       1  0.222222       3     4     5   0
# ...

# %%
tb.pop('cartão')
tb
# Out:
#      idade      sexo  col4  col5  -1
# L1       1  0.222222     4     5   0
# L2       1  0.222222     4     5   0
# L3       1  0.222222     4     5   0
# L4       1  0.222222     4     5   0
# L5       1  0.222222     4     5   0
# L6       1  0.222222     4     5   0
# L7       1  0.222222     4     5   0
# L8       1  0.222222     4     5   0
# L9       1  0.222222     4     5   0
# L10      1  0.222222     4     5   0
# 10       1  0.222222     4     5   0
# 11       1  0.222222     4     5   0
# 12       1  0.222222     4     5   0
# 13       1  0.222222     4     5   0
# 14       1  0.222222     4     5   0
# 15       1  0.222222     4     5   0
# 16       1  0.222222     4     5   0
# 17       1  0.222222     4     5   0
# 18       1  0.222222     4     5   0
# 19       1  0.222222     4     5   0
# 20       1  0.222222     4     5   0
# 21       1  0.222222     4     5   0
# 22       1  0.222222     4     5   0
# 23       1  0.222222     4     5   0
# ...

# %%
tb['new col']=range(len(tb))
tb
# Out:
#      idade      sexo  col4  col5  -1  new col
# L1       1  0.222222     4     5   0        0
# L2       1  0.222222     4     5   0        1
# L3       1  0.222222     4     5   0        2
# L4       1  0.222222     4     5   0        3
# L5       1  0.222222     4     5   0        4
# L6       1  0.222222     4     5   0        5
# L7       1  0.222222     4     5   0        6
# L8       1  0.222222     4     5   0        7
# L9       1  0.222222     4     5   0        8
# L10      1  0.222222     4     5   0        9
# 10       1  0.222222     4     5   0       10
# 11       1  0.222222     4     5   0       11
# 12       1  0.222222     4     5   0       12
# 13       1  0.222222     4     5   0       13
# 14       1  0.222222     4     5   0       14
# 15       1  0.222222     4     5   0       15
# 16       1  0.222222     4     5   0       16
# 17       1  0.222222     4     5   0       17
# 18       1  0.222222     4     5   0       18
# ...

# %%
tb['outra col']= np.repeat(np.nan,len(tb))
tb
# Out:
#      idade      sexo  col4  col5  -1  new col  outra col
# L1       1  0.222222     4     5   0        0        NaN
# L2       1  0.222222     4     5   0        1        NaN
# L3       1  0.222222     4     5   0        2        NaN
# L4       1  0.222222     4     5   0        3        NaN
# L5       1  0.222222     4     5   0        4        NaN
# L6       1  0.222222     4     5   0        5        NaN
# L7       1  0.222222     4     5   0        6        NaN
# L8       1  0.222222     4     5   0        7        NaN
# L9       1  0.222222     4     5   0        8        NaN
# L10      1  0.222222     4     5   0        9        NaN
# 10       1  0.222222     4     5   0       10        NaN
# 11       1  0.222222     4     5   0       11        NaN
# 12       1  0.222222     4     5   0       12        NaN
# 13       1  0.222222     4     5   0       13        NaN
# 14       1  0.222222     4     5   0       14        NaN
# ...

# %%
tb['random']= np.random.rand(len(tb))+1
tb
# Out:
#      idade      sexo  col4  col5  -1  new col  outra col    random
# L1       1  0.222222     4     5   0        0        NaN  1.671129
# L2       1  0.222222     4     5   0        1        NaN  1.606499
# L3       1  0.222222     4     5   0        2        NaN  1.638823
# L4       1  0.222222     4     5   0        3        NaN  1.208282
# L5       1  0.222222     4     5   0        4        NaN  1.028642
# L6       1  0.222222     4     5   0        5        NaN  1.730033
# L7       1  0.222222     4     5   0        6        NaN  1.734424
# L8       1  0.222222     4     5   0        7        NaN  1.150459
# L9       1  0.222222     4     5   0        8        NaN  1.991266
# L10      1  0.222222     4     5   0        9        NaN  1.986513
# 10       1  0.222222     4     5   0       10        NaN  1.484325
# 11       1  0.222222     4     5   0       11        NaN  1.558607
# 12       1  0.222222     4     5   0       12        NaN  1.752467
# ...
