# %% [markdown]
# #  EAD1
# aluno: Joel Campos Teixeira

# %%
import numpy as np
import pandas as pd  # carregando as bibliotecas

# %%
damasc = pd.read_csv('ibge-mas-10000.csv') # importando dados masc

# %%
damasc.head()
# Out:
#         nome  regiao     freq  rank sexo
# 0       JOSE       0  5732508     1    M
# 1       JOAO       0  2971935     2    M
# 2    ANTONIO       0  2567494     3    M
# 3  FRANCISCO       0  1765197     4    M
# 4     CARLOS       0  1483121     5    M

# %%
dafem=pd.read_csv('ibge-fem-10000.csv')  # importar dado fem

# %%
dafem.head()
# Out:
#         nome  regiao      freq  rank sexo
# 0      MARIA       0  11694738     1    F
# 1        ANA       0   3079729     2    F
# 2  FRANCISCA       0    721637     3    F
# 3    ANTONIA       0    588783     4    F
# 4    ADRIANA       0    565621     5    F

# %%
dt= pd.concat([damasc,dafem])
dt
# Out:
#             nome  regiao     freq   rank sexo
# 0           JOSE       0  5732508      1    M
# 1           JOAO       0  2971935      2    M
# 2        ANTONIO       0  2567494      3    M
# 3      FRANCISCO       0  1765197      4    M
# 4         CARLOS       0  1483121      5    M
# ...          ...     ...      ...    ...  ...
# 9995       LUINE       0      337  10013    F
# 9996     SILBENE       0      337  10001    F
# 9997    GERSIANE       0      337  10003    F
# 9998  DALVANEIDE       0      337   9995    F
# 9999    DERENICE       0      337  10012    F
#
# [20000 rows x 5 columns]

# %%
dt.to_csv('dadosibge.csv',index= False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dt.to_csv('dadosibge.csv',index= False)
#
# NameError: name 'dt' is not defined

# %%
df= pd.read_csv('dadosibge.csv')

# %%
df
# Out:
#              nome  regiao     freq   rank sexo
# 0            JOSE       0  5732508      1    M
# 1            JOAO       0  2971935      2    M
# 2         ANTONIO       0  2567494      3    M
# 3       FRANCISCO       0  1765197      4    M
# 4          CARLOS       0  1483121      5    M
# ...           ...     ...      ...    ...  ...
# 19995       LUINE       0      337  10013    F
# 19996     SILBENE       0      337  10001    F
# 19997    GERSIANE       0      337  10003    F
# 19998  DALVANEIDE       0      337   9995    F
# 19999    DERENICE       0      337  10012    F
#
# [20000 rows x 5 columns]

# %%
df.head()
# Out:
#         nome  regiao     freq  rank sexo
# 0       JOSE       0  5732508     1    M
# 1       JOAO       0  2971935     2    M
# 2    ANTONIO       0  2567494     3    M
# 3  FRANCISCO       0  1765197     4    M
# 4     CARLOS       0  1483121     5    M

# %%
#verificando quantidade de valores em regiao
regiao =df['regiao'].value_counts()
regiao2= sum(df['regiao'].value_counts())
regiao2
# Out:
# 20000

# %%
regiao1= df.drop(labels=['regiao'],axis= 1)

# %%
regiao1
# Out:
#              nome     freq   rank sexo
# 0            JOSE  5732508      1    M
# 1            JOAO  2971935      2    M
# 2         ANTONIO  2567494      3    M
# 3       FRANCISCO  1765197      4    M
# 4          CARLOS  1483121      5    M
# ...           ...      ...    ...  ...
# 19995       LUINE      337  10013    F
# 19996     SILBENE      337  10001    F
# 19997    GERSIANE      337  10003    F
# 19998  DALVANEIDE      337   9995    F
# 19999    DERENICE      337  10012    F
#
# [20000 rows x 4 columns]

# %%
#importando as bibliotecas
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
#contar frequencia por sexo
sexo = regiao1['sexo'].value_counts().index
sexo
# Out:
# Index(['M', 'F'], dtype='object', name='sexo')

# %%
plt.pyplot.bar(regiao1['sexo'].value_counts().index,regiao1['sexo'].value_counts().values, color='red',edgecolor='black')
plt.pyplot.title('DISTRIBUIÇÃO DE GENERO')
plt.pyplot.xlabel('Genero')
plt.pyplot.ylabel('Quantidade')
plt.pyplot.show()
plt.b

# %%
df.head()
# pegando informações do topo da tabela
# Out:
#         nome  regiao     freq  rank sexo
# 0       JOSE       0  5732508     1    M
# 1       JOAO       0  2971935     2    M
# 2    ANTONIO       0  2567494     3    M
# 3  FRANCISCO       0  1765197     4    M
# 4     CARLOS       0  1483121     5    M

# %%
# pegando informações sobre as colunas 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nome    20000 non-null  object
#  1   regiao  20000 non-null  int64
#  2   freq    20000 non-null  int64
#  3   rank    20000 non-null  int64
#  4   sexo    20000 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 781.4+ KB

# %%
# descrição sobre a coluna sexo: quantidade , tipos e a maior frequencia
df['sexo'].describe()
# Out:
# count     20000
# unique        2
# top           M
# freq      10000
# Name: sexo, dtype: object

# %%
#informações sobre as ultimas linhas da tabela
df.tail()
# Out:
#              nome  regiao  freq   rank sexo
# 19995       LUINE       0   337  10013    F
# 19996     SILBENE       0   337  10001    F
# 19997    GERSIANE       0   337  10003    F
# 19998  DALVANEIDE       0   337   9995    F
# 19999    DERENICE       0   337  10012    F

# %%
#descrevendo a coluna rank
df['rank'].describe()
# Out:
# count    20000.000000
# mean      5000.504950
# std       2886.832079
# min          1.000000
# 25%       2500.750000
# 50%       5000.500000
# 75%       7500.250000
# max      10014.000000
# Name: rank, dtype: float64

# %%
# info sobre rank
df['rank'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 20000 entries, 0 to 19999
# Series name: rank
# Non-Null Count  Dtype
# --------------  -----
# 20000 non-null  int64
# dtypes: int64(1)
# memory usage: 156.4 KB

# %%
# proporção da coluna sexo
prop=df['sexo'].value_counts(normalize=True) * 100
prop
# Out:
# sexo
# M    50.0
# F    50.0
# Name: proportion, dtype: float64

# %%
# nomes mais frequentes
nomes_mais_frequentes = df.groupby(['nome']).sum().sort_values(by='freq',ascending=False).head(10)
nomes_mais_frequentes
# Out:
#                freq  rank sexo
# nome
# MARIA      11734129   282   MF
# JOSE        5754529   548   MF
# ANA         3089858   755   MF
# JOAO        2984119   790   MF
# ANTONIO     2576348  1008   MF
# FRANCISCO   1772197  1174   MF
# CARLOS      1489191  1292   MF
# PAULO       1423262  1422   MF
# PEDRO       1219605  1302   MF
# LUCAS       1127310   894   MF

# %%
df = df.drop(['regiao'],axis=1)

# %%
df
# Out:
#              nome     freq   rank sexo
# 0            JOSE  5732508      1    M
# 1            JOAO  2971935      2    M
# 2         ANTONIO  2567494      3    M
# 3       FRANCISCO  1765197      4    M
# 4          CARLOS  1483121      5    M
# ...           ...      ...    ...  ...
# 19995       LUINE      337  10013    F
# 19996     SILBENE      337  10001    F
# 19997    GERSIANE      337  10003    F
# 19998  DALVANEIDE      337   9995    F
# 19999    DERENICE      337  10012    F
#
# [20000 rows x 4 columns]

# %%
nomes_menos_usados= df.groupby(['nome']).sum().sort_values(by='freq',ascending=True).head(10)
nomes_menos_usados
# Out:
#             freq  rank sexo
# nome
# CARLOA       265  9991    M
# KELVISON     265  9997    M
# RUBIAN       265  9993    M
# ELIETON      265  9998    M
# TARCILO      265  9999    M
# LEOZIR       265  9992    M
# PROTAZIO     265  9978    M
# CLAUDEONOR   265  9995    M
# DEUSDEDITH   265  9982    M
# KENID        265  9983    M
